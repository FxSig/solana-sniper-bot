# %%
# @title Installation, git clone and requirements
# !git clone https://github.com/adharna/solana-sniper-bot && cd solana-sniper-bot/ && pip3 install -r requirements.txt

# %%
# @title config.ini
import configparser
x = configparser.ConfigParser()
x.read("/content/solana-sniper-bot/config.ini")
x["user"]["private_key"] = 'Change your private key here' # @param {type:"string"}

f = open("/content/solana-sniper-bot/config.ini", "w")
x.write(f)
f.close()

# %%
# !cat /content/solana-sniper-bot/config.ini
# Out:
# [user]
# private_key = Your Private Key Here
#
# [config]
# is_buy = 1
# is_sell = 0
# pool_size = 600
# sol_amount = 0.0055
# wait_seconds = 30
#
# [solanaConfig]
# main_url = https://api.mainnet-beta.solana.com
# wss_url = wss://orbital-polished-rain.solana-mainnet.quiknode.pro/aa92ba0b474b53f9ee8473aaa0a0370ef3dcfb0e/
# raydium_lp_v4 = 675kPX9MHTjS2zt1qfr1NYHuzeLXfQM9H24wFSUt1Mp8
# log_instruction = initialize2

# %%
# %%shell
# cd /content/solana-sniper-bot/ && python /content/solana-sniper-bot/main.py
# Out:
# Starting Solana Sniper on Raydium pool
# Scanning Raydium: 0
# Scanning Raydium: 100
# Scanning Raydium: 200
# Scanning Raydium: 300
# Scanning Raydium: 400
# Scanning Raydium: 500
# Scanning Raydium: 600
# Scanning Raydium: 700
# Scanning Raydium: 800
# Scanning Raydium: 900
# Scanning Raydium: 1000
# Scanning Raydium: 1100
# Scanning Raydium: 1200
# Scanning Raydium: 1300
# Scanning Raydium: 1400
# Scanning Raydium: 1500
# Scanning Raydium: 1600
# Scanning Raydium: 1700
# Scanning Raydium: 1800
# Scanning Raydium: 1900
# Scanning Raydium: 2000
# Scanning Raydium: 2100
# Scanning Raydium: 2200
# Scanning Raydium: 2300
# Scanning Raydium: 2400
# Scanning Raydium: 2500
# Scanning Raydium: 2600
# Scanning Raydium: 2700
# Scanning Raydium: 2800
# Scanning Raydium: 2900
# Scanning Raydium: 3000
# Scanning Raydium: 3100
# Scanning Raydium: 3200
# Scanning Raydium: 3300
# Scanning Raydium: 3400
# Scanning Raydium: 3500
# Scanning Raydium: 3600
# Scanning Raydium: 3700
# ...
